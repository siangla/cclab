# %%
import pandas as pd
import seaborn as sns
from pycaret.classification import setup
from pycaret.classification import compare_models
from pycaret.classification import create_model
import time


# 讀取資料集
data = pd.read_csv('D2.csv')

# 設置 PyCaret 的設定
setup(data, target='GDM')  

"""
# 記錄開始時間
start_time = time.time()

# 比較不同模型的性能
best_model = compare_models()

print(type(best_model))

# 記錄結束時間
end_time = time.time()

# 計算花費時間
elapsed_time = end_time - start_time

# 顯示花費時間
print("訓練時間：{:.2f} 秒".format(elapsed_time))
"""
# Out:
# <style type="text/css">
# #T_e5084_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e5084">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5084_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e5084_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5084_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5084_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e5084_row0_col1" class="data row0 col1" >4225</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5084_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e5084_row1_col1" class="data row1 col1" >GDM</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5084_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e5084_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5084_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e5084_row3_col1" class="data row3 col1" >(3997, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e5084_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e5084_row4_col1" class="data row4 col1" >(3997, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e5084_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e5084_row5_col1" class="data row5 col1" >(2797, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e5084_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e5084_row6_col1" class="data row6 col1" >(1200, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e5084_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e5084_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e5084_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e5084_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e5084_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e5084_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e5084_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e5084_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e5084_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e5084_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e5084_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e5084_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e5084_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e5084_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e5084_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e5084_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e5084_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e5084_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e5084_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e5084_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e5084_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e5084_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e5084_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e5084_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e5084_row18_col1" class="data row18 col1" >03b8</td>
#     </tr>
#   </tbody>
# </table>
# '\n# 記錄開始時間\nstart_time = time.time()\n\n# 比較不同模型的性能\nbest_model = compare_models()\n\nprint(type(best_model))\n\n# 記錄結束時間\nend_time = time.time()\n\n# 計算花費時間\nelapsed_time = end_time - start_time\n\n# 顯示花費時間\nprint("訓練時間：{:.2f} 秒".format(elapsed_time))\n'

# %%
# 建立一個決策樹分類器模型
dt = create_model('dt')

# 檢查模型的特徵重要性
if hasattr(dt, 'feature_importances_'):
    feature_importances = dt.feature_importances_
    feature_names = data.columns
    # 顯示特徵名稱及特徵重要性
    for i, feature_importance in enumerate(feature_importances):
        feature_name = feature_names[i]
        print("特徵名稱: {}, 特徵重要性: {}".format(feature_name, feature_importance))
else:
    print("此模型不提供特徵重要性。")
    
# 選擇重要性高的特徵
if hasattr(dt, 'feature_importances_'):
    selected_features = [f for f, importance in zip(data.columns, dt.feature_importances_) if importance > 0.01]
    print("重要性高於閾值的特徵:", selected_features)
else:
    print("此模型不提供特徵重要性。")
# Out:
# <style type="text/css">
# #T_2e4f0_row10_col0, #T_2e4f0_row10_col1, #T_2e4f0_row10_col2, #T_2e4f0_row10_col3, #T_2e4f0_row10_col4, #T_2e4f0_row10_col5, #T_2e4f0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2e4f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e4f0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2e4f0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2e4f0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2e4f0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2e4f0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2e4f0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2e4f0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e4f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e4f0_row0_col0" class="data row0 col0" >0.8929</td>
#       <td id="T_2e4f0_row0_col1" class="data row0 col1" >0.7762</td>
#       <td id="T_2e4f0_row0_col2" class="data row0 col2" >0.6250</td>
#       <td id="T_2e4f0_row0_col3" class="data row0 col3" >0.5263</td>
#       <td id="T_2e4f0_row0_col4" class="data row0 col4" >0.5714</td>
#       <td id="T_2e4f0_row0_col5" class="data row0 col5" >0.5107</td>
#       <td id="T_2e4f0_row0_col6" class="data row0 col6" >0.5132</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e4f0_row1_col0" class="data row1 col0" >0.8964</td>
#       <td id="T_2e4f0_row1_col1" class="data row1 col1" >0.7510</td>
#       <td id="T_2e4f0_row1_col2" class="data row1 col2" >0.5625</td>
#       <td id="T_2e4f0_row1_col3" class="data row1 col3" >0.5455</td>
#       <td id="T_2e4f0_row1_col4" class="data row1 col4" >0.5538</td>
#       <td id="T_2e4f0_row1_col5" class="data row1 col5" >0.4953</td>
#       <td id="T_2e4f0_row1_col6" class="data row1 col6" >0.4954</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e4f0_row2_col0" class="data row2 col0" >0.9107</td>
#       <td id="T_2e4f0_row2_col1" class="data row2 col1" >0.8271</td>
#       <td id="T_2e4f0_row2_col2" class="data row2 col2" >0.7188</td>
#       <td id="T_2e4f0_row2_col3" class="data row2 col3" >0.5897</td>
#       <td id="T_2e4f0_row2_col4" class="data row2 col4" >0.6479</td>
#       <td id="T_2e4f0_row2_col5" class="data row2 col5" >0.5973</td>
#       <td id="T_2e4f0_row2_col6" class="data row2 col6" >0.6012</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e4f0_row3_col0" class="data row3 col0" >0.9286</td>
#       <td id="T_2e4f0_row3_col1" class="data row3 col1" >0.8151</td>
#       <td id="T_2e4f0_row3_col2" class="data row3 col2" >0.6667</td>
#       <td id="T_2e4f0_row3_col3" class="data row3 col3" >0.7097</td>
#       <td id="T_2e4f0_row3_col4" class="data row3 col4" >0.6875</td>
#       <td id="T_2e4f0_row3_col5" class="data row3 col5" >0.6472</td>
#       <td id="T_2e4f0_row3_col6" class="data row3 col6" >0.6476</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e4f0_row4_col0" class="data row4 col0" >0.9143</td>
#       <td id="T_2e4f0_row4_col1" class="data row4 col1" >0.8201</td>
#       <td id="T_2e4f0_row4_col2" class="data row4 col2" >0.6970</td>
#       <td id="T_2e4f0_row4_col3" class="data row4 col3" >0.6216</td>
#       <td id="T_2e4f0_row4_col4" class="data row4 col4" >0.6571</td>
#       <td id="T_2e4f0_row4_col5" class="data row4 col5" >0.6083</td>
#       <td id="T_2e4f0_row4_col6" class="data row4 col6" >0.6096</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2e4f0_row5_col0" class="data row5 col0" >0.9107</td>
#       <td id="T_2e4f0_row5_col1" class="data row5 col1" >0.7787</td>
#       <td id="T_2e4f0_row5_col2" class="data row5 col2" >0.6061</td>
#       <td id="T_2e4f0_row5_col3" class="data row5 col3" >0.6250</td>
#       <td id="T_2e4f0_row5_col4" class="data row5 col4" >0.6154</td>
#       <td id="T_2e4f0_row5_col5" class="data row5 col5" >0.5649</td>
#       <td id="T_2e4f0_row5_col6" class="data row5 col6" >0.5650</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2e4f0_row6_col0" class="data row6 col0" >0.8786</td>
#       <td id="T_2e4f0_row6_col1" class="data row6 col1" >0.7343</td>
#       <td id="T_2e4f0_row6_col2" class="data row6 col2" >0.5455</td>
#       <td id="T_2e4f0_row6_col3" class="data row6 col3" >0.4865</td>
#       <td id="T_2e4f0_row6_col4" class="data row6 col4" >0.5143</td>
#       <td id="T_2e4f0_row6_col5" class="data row6 col5" >0.4452</td>
#       <td id="T_2e4f0_row6_col6" class="data row6 col6" >0.4461</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2e4f0_row7_col0" class="data row7 col0" >0.8853</td>
#       <td id="T_2e4f0_row7_col1" class="data row7 col1" >0.7992</td>
#       <td id="T_2e4f0_row7_col2" class="data row7 col2" >0.6875</td>
#       <td id="T_2e4f0_row7_col3" class="data row7 col3" >0.5000</td>
#       <td id="T_2e4f0_row7_col4" class="data row7 col4" >0.5789</td>
#       <td id="T_2e4f0_row7_col5" class="data row7 col5" >0.5145</td>
#       <td id="T_2e4f0_row7_col6" class="data row7 col6" >0.5232</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2e4f0_row8_col0" class="data row8 col0" >0.8817</td>
#       <td id="T_2e4f0_row8_col1" class="data row8 col1" >0.7700</td>
#       <td id="T_2e4f0_row8_col2" class="data row8 col2" >0.6250</td>
#       <td id="T_2e4f0_row8_col3" class="data row8 col3" >0.4878</td>
#       <td id="T_2e4f0_row8_col4" class="data row8 col4" >0.5479</td>
#       <td id="T_2e4f0_row8_col5" class="data row8 col5" >0.4811</td>
#       <td id="T_2e4f0_row8_col6" class="data row8 col6" >0.4860</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2e4f0_row9_col0" class="data row9 col0" >0.9068</td>
#       <td id="T_2e4f0_row9_col1" class="data row9 col1" >0.8250</td>
#       <td id="T_2e4f0_row9_col2" class="data row9 col2" >0.7188</td>
#       <td id="T_2e4f0_row9_col3" class="data row9 col3" >0.5750</td>
#       <td id="T_2e4f0_row9_col4" class="data row9 col4" >0.6389</td>
#       <td id="T_2e4f0_row9_col5" class="data row9 col5" >0.5861</td>
#       <td id="T_2e4f0_row9_col6" class="data row9 col6" >0.5910</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2e4f0_row10_col0" class="data row10 col0" >0.9006</td>
#       <td id="T_2e4f0_row10_col1" class="data row10 col1" >0.7897</td>
#       <td id="T_2e4f0_row10_col2" class="data row10 col2" >0.6453</td>
#       <td id="T_2e4f0_row10_col3" class="data row10 col3" >0.5667</td>
#       <td id="T_2e4f0_row10_col4" class="data row10 col4" >0.6013</td>
#       <td id="T_2e4f0_row10_col5" class="data row10 col5" >0.5451</td>
#       <td id="T_2e4f0_row10_col6" class="data row10 col6" >0.5478</td>
#     </tr>
#     <tr>
#       <th id="T_2e4f0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2e4f0_row11_col0" class="data row11 col0" >0.0154</td>
#       <td id="T_2e4f0_row11_col1" class="data row11 col1" >0.0309</td>
#       <td id="T_2e4f0_row11_col2" class="data row11 col2" >0.0591</td>
#       <td id="T_2e4f0_row11_col3" class="data row11 col3" >0.0683</td>
#       <td id="T_2e4f0_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# 特徵名稱: Age, 特徵重要性: 0.057924407980678536
# 特徵名稱: Weight, 特徵重要性: 0.05460903539998726
# 特徵名稱: Height, 特徵重要性: 0.060387203302907776
# 特徵名稱: BMI, 特徵重要性: 0.037352379929133095
# 特徵名稱: Ethnicity, 特徵重要性: 0.029369433820574064
# 特徵名稱: PreviousUterineSurgery, 特徵重要性: 0.004089417993229969
# 特徵名稱: Gravida, 特徵重要性: 0.01823942437822065
# 特徵名稱: VitaminDlevelblood, 特徵重要性: 0.018140204183976116
# 特徵名稱: SystolicBloodPressureCuff, 特徵重要性: 0.06643520606176719
# 特徵名稱: DiastolicBloodPressure, 特徵重要性: 0.05713605755193996
# 特徵名稱: Glucoselevel0minblood, 特徵重要性: 0.5963172293975854
# 重要性高於閾值的特徵: ['Age', 'Weight', 'Height', 'BMI', 'Ethnicity', 'Gravida', 'VitaminDlevelblood', 'SystolicBloodPressureCuff', 'DiastolicBloodPressure', 'Glucoselevel0minblood']

# %%
# Out:
# 重要性高於閾值的特徵: ['Age', 'Weight', 'Height', 'BMI', 'Ethnicity', 'PreviousUterineSurgery', 'Gravida', 'VitaminDlevelblood', 'SystolicBloodPressureCuff', 'DiastolicBloodPressure']
