# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split

# 讀取數據集
data = pd.read_csv("GDM_Model1.csv")

# %%
#數據分割
#將數據集分為訓練集和測試集
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9769 entries, 9598 to 7270
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    9769 non-null   int64
#  1   Weight                 9769 non-null   float64
#  2   Height                 9769 non-null   float64
#  3   BMI                    9769 non-null   float64
#  4   Ethnicity              9769 non-null   int64
#  5   Gravida                9769 non-null   int64
#  6   Glucoselevel0minblood  9769 non-null   float64
#  7   GDM                    9769 non-null   int64
# dtypes: float64(4), int64(4)
# memory usage: 686.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2443 entries, 2919 to 3794
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    2443 non-null   int64
# ...

# %%
#Y/N個數
fig, ax =plt.subplots(figsize=(10,5))
print(train_data.GDM.value_counts())

sns.countplot(data=test_data,x='GDM',ax=ax)
# Out:
# 0    8859
# 1     910
# Name: GDM, dtype: int64
# <AxesSubplot: xlabel='GDM', ylabel='count'>

# %%
#模型選擇
from pycaret.classification import *

#初始化PyCaret
#setup(data=train_data, target='GDM', session_id=42)
clf1 = setup(data=train_data, 
             target='GDM', 
             fold_shuffle=True, 
             session_id=2, 
             preprocess=False)

#排除模型
exclude_models = ['ridge','dummy']

#比較不同的分類器
best_model = compare_models() #best_model = compare_models() #
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a32e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a32e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6a32e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a32e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a32e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6a32e_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6a32e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a32e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6a32e_row1_col1" class="data row1 col1" >GDM</td>
#     </tr>
#     <tr>
#       <th id="T_6a32e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a32e_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %%
#模型訓練
#提取前5個及各分數最高的模型建立
#lr = create_model('lr')
#lda = create_model('lda')
xgboost = create_model('xgboost')
rf = create_model('rf')
ada = create_model('ada')
gbc = create_model('gbc')
lightgbm = create_model('lightgbm')
#ridge = create_model('ridge')
#dt = create_model('dt')
#dummy = create_model('dummy')
# Out:
# <style type="text/css">
# #T_32b0a_row10_col0, #T_32b0a_row10_col1, #T_32b0a_row10_col2, #T_32b0a_row10_col3, #T_32b0a_row10_col4, #T_32b0a_row10_col5, #T_32b0a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_32b0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32b0a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_32b0a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_32b0a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_32b0a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_32b0a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_32b0a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_32b0a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
stacker1_3 = stack_models(estimator_list = [xgboost,rf,ada,gbc,lightgbm], meta_model =rf ) #
# Out:
# <style type="text/css">
# #T_f11a1_row10_col0, #T_f11a1_row10_col1, #T_f11a1_row10_col2, #T_f11a1_row10_col3, #T_f11a1_row10_col4, #T_f11a1_row10_col5, #T_f11a1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f11a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f11a1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f11a1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f11a1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f11a1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f11a1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f11a1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f11a1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
#stacker1_1 = stack_models(estimator_list = [lda,ada,lr,gbc,lightgbm], meta_model =lr ) #
stacker1_3
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('Extreme Gradient Boosting',
#                                 XGBClassifier(base_score=None, booster='gbtree',
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               gpu_id=None, grow_policy=None,
#                                               importance_type=None,
#                                               interacti...
# ...

# %%
stacker_model = tune_model(stacker1_3)
# Out:
# <style type="text/css">
# #T_caddb_row10_col0, #T_caddb_row10_col1, #T_caddb_row10_col2, #T_caddb_row10_col3, #T_caddb_row10_col4, #T_caddb_row10_col5, #T_caddb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_caddb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_caddb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_caddb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_caddb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_caddb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_caddb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_caddb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_caddb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
stacker_model
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('Extreme Gradient Boosting',
#                                 XGBClassifier(base_score=None, booster='gbtree',
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               gpu_id=None, grow_policy=None,
#                                               importance_type=None,
#                                               interacti...
# ...

# %%
#save_model(stacker_model,'stacker_model1_1')
save_model(stacker_model,'stacker1_3')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\User\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('trained_model',
#                   StackingClassifier(cv=5,
#                                      estimators=[('Extreme Gradient Boosting',
#                                                   XGBClassifier(base_score=None,
#                                                                 booster='gbtree',
#                                                                 callbacks=None,
#                                                                 colsample_bylevel=None,
#                                                                 colsample_bynode=None,
#                                                                 colsample_bytree=None,
#                                                                 early_stopping_rounds=None,
# ...

# %%
#model1_1 = load_model('stacker_model1_1')
#model1_2 = load_model('stacker_model1_2')
model1_3 = load_model('stacker1_3')
#pred1_1 = predict_model(model1_1,data = test_data)
#pred1_2 = predict_model(model1_2,data = test_data)
pred1_3 = predict_model(model1_3,data = test_data)
pred2 = predict_model(rf,data = test_data)

pred1_3.head()
pred2.head()
# Out:
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_1d436">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d436_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1d436_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1d436_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1d436_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1d436_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1d436_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1d436_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1d436_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d436_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred1_3['GDM'],pred1_3['prediction_label'])
# Out:
# 0.9705280392959476

# %%
accuracy_score(pred2['GDM'],pred2['prediction_label'])
# Out:
# 0.9713467048710601

# %%
#評估調整後的模型
evaluate_model(model1_3)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#模型集成
#使用Bagging集成多個最優分類器
#ensemble_model = ensemble_model(model1_2, method='Bagging')
# Out:
# <style type="text/css">
# #T_0c141_row10_col0, #T_0c141_row10_col1, #T_0c141_row10_col2, #T_0c141_row10_col3, #T_0c141_row10_col4, #T_0c141_row10_col5, #T_0c141_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0c141">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c141_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0c141_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0c141_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0c141_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0c141_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0c141_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0c141_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
#模型評估
from sklearn.metrics import classification_report, confusion_matrix

#預測測試集數據
predictions = predict_model(stacker_model, data=test_data)

#計算混淆矩陣和分類報告
cm = confusion_matrix(predictions['GDM'], predictions['prediction_label'])
report = classification_report(predictions['GDM'], predictions['prediction_label'])

#輸出混淆矩陣和分類報告
print("Confusion matrix:")
print(cm)
print("Classification report:")
print(report)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e8aff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8aff_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e8aff_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e8aff_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e8aff_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e8aff_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e8aff_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e8aff_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e8aff_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8aff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8aff_row0_col0" class="data row0 col0" >Stacking Classifier</td>
# ...

# %%
#模型解釋性分析
#解釋模型中各個特徵的重要性
interpret_model(lightgbm)
#interpret_model(lr)

# %%
#繪製ROC曲線和KS曲線
plot_model(stacker_model, plot='auc')
plot_model(rf, plot='auc')
#plot_model(model1_2, plot='ks')

# %%
#研究結果分析
#繪製特徵重要性圖表
#plot_model(stacker_model, plot='feature')

#繪製錯誤分析圖表
plot_model(stacker_model, plot='error')

#繪製分類器學習曲線和驗證曲線
plot_model(stacker_model, plot='learning')
plot_model
# Out:
# <function pycaret.classification.functional.plot_model(estimator, plot: str = 'auc', scale: float = 1, save: bool = False, fold: Union[int, Any, NoneType] = None, fit_kwargs: Optional[dict] = None, plot_kwargs: Optional[dict] = None, groups: Union[str, Any, NoneType] = None, use_train_data: bool = False, verbose: bool = True, display_format: Optional[str] = None) -> Optional[str]>

# %%
summary_plot = plot_model(rf, plot='summary')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1452\1517778059.py in <cell line: 1>()
# ----> 1 summary_plot = plot_model(rf, plot='summary')
#
# D:\anaconda3\lib\site-packages\pycaret\utils\generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# D:\anaconda3\lib\site-packages\pycaret\classification\functional.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, use_train_data, verbose, display_format)
#    1745     """
#    1746
# -> 1747     return _CURRENT_EXPERIMENT.plot_model(
#    1748         estimator=estimator,
#    1749         plot=plot,
#
# ...
