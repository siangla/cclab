# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split

# 讀取數據集
data = pd.read_csv("GDM_Model2.csv")

# %%
#數據分割
#將數據集分為訓練集和測試集
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3197 entries, 1575 to 3174
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        3197 non-null   int64
#  1   BMI                        3197 non-null   float64
#  2   Gravida                    3197 non-null   int64
#  3   SystolicBloodPressureCuff  3197 non-null   int64
#  4   DiastolicBloodPressure     3197 non-null   int64
#  5   Glucoselevel0minblood      3197 non-null   float64
#  6   GDM                        3197 non-null   int64
# dtypes: float64(2), int64(5)
# memory usage: 199.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1760 to 2989
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        800 non-null    int64
# ...

# %%
#Y/N個數
fig, ax =plt.subplots(figsize=(10,5))
print(train_data.GDM.value_counts())

sns.countplot(data=train_data,x='GDM',ax=ax)
# Out:
# 0    2825
# 1     372
# Name: GDM, dtype: int64
# <AxesSubplot: xlabel='GDM', ylabel='count'>

# %%
#Y/N個數
fig, ax =plt.subplots(figsize=(10,5))
print(test_data.GDM.value_counts())

sns.countplot(data=test_data,x='GDM',ax=ax)
# Out:
# 0    709
# 1     91
# Name: GDM, dtype: int64
# <AxesSubplot: xlabel='GDM', ylabel='count'>

# %%
#模型選擇
from pycaret.classification import *

#初始化PyCaret
#setup(data=train_data, target='GDM', session_id=42)
clf1 = setup(data=test_data, 
             target='GDM', 
             fold_shuffle=True, 
             session_id=2, 
             preprocess=False)

#排除模型
exclude_models = ['ridge','dummy']

#比較不同的分類器
best_model = compare_models()#exclude=exclude_models
# Out:
# <style type="text/css">
# </style>
# <table id="T_580df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_580df_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_580df_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_580df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_580df_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_580df_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_580df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_580df_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_580df_row1_col1" class="data row1 col1" >GDM</td>
#     </tr>
#     <tr>
#       <th id="T_580df_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_580df_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %%
#模型訓練
#提取前5個及各分數最高的模型建立
rf = create_model('rf')
gbc = create_model('gbc')
lightgbm = create_model('lightgbm')
xgboost = create_model('xgboost')
lr = create_model('lr')
#lda = create_model('lda')
#et = create_model('et')
#ada = create_model('ada')
#ridge = create_model('ridge')
#dummy = create_model('dummy')
#knn = create_model('knn')
#qda = create_model('qda')
#nb = create_model('nb')
#dt = create_model('dt')
#svm = create_model('svm')
# Out:
# <style type="text/css">
# #T_3d144_row10_col0, #T_3d144_row10_col1, #T_3d144_row10_col2, #T_3d144_row10_col3, #T_3d144_row10_col4, #T_3d144_row10_col5, #T_3d144_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3d144">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d144_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3d144_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3d144_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3d144_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3d144_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3d144_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3d144_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
stacker = stack_models(estimator_list = [rf,gbc,lightgbm,xgboost,lr], meta_model = rf)
# Out:
# <style type="text/css">
# #T_136a4_row10_col0, #T_136a4_row10_col1, #T_136a4_row10_col2, #T_136a4_row10_col3, #T_136a4_row10_col4, #T_136a4_row10_col5, #T_136a4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_136a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_136a4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_136a4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_136a4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_136a4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_136a4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_136a4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_136a4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
stacker
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('Random Forest Classifier',
#                                 RandomForestClassifier(bootstrap=True,
#                                                        ccp_alpha=0.0,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=None,
#                                                        max_features='sqrt',
#                                                        max_leaf_nodes=None,
#                                                        max_samples=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
# ...

# %%
stacker_model = tune_model(stacker)
# Out:
# <style type="text/css">
# #T_060eb_row10_col0, #T_060eb_row10_col1, #T_060eb_row10_col2, #T_060eb_row10_col3, #T_060eb_row10_col4, #T_060eb_row10_col5, #T_060eb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_060eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_060eb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_060eb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_060eb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_060eb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_060eb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_060eb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_060eb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
stacker_model
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('Random Forest Classifier',
#                                 RandomForestClassifier(bootstrap=True,
#                                                        ccp_alpha=0.0,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=None,
#                                                        max_features='sqrt',
#                                                        max_leaf_nodes=None,
#                                                        max_samples=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
# ...

# %%
save_model(stacker_model,'stacker_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\User\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('trained_model',
#                   StackingClassifier(cv=5,
#                                      estimators=[('Random Forest Classifier',
#                                                   RandomForestClassifier(bootstrap=True,
#                                                                          ccp_alpha=0.0,
#                                                                          class_weight=None,
#                                                                          criterion='gini',
#                                                                          max_depth=None,
#                                                                          max_features='sqrt',
#                                                                          max_leaf_nodes=None,
# ...

# %%
#进進行預測
model = load_model('stacker_model')
pred = predict_model(model,data = test_data)
pred2 = predict_model(rf,data = test_data)

pred.head()
pred2.head()
# Out:
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_a9b1a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9b1a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a9b1a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a9b1a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a9b1a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a9b1a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a9b1a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a9b1a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a9b1a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9b1a_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred['GDM'],pred['prediction_label'])
# Out:
# 0.98625

# %%
accuracy_score(pred2['GDM'],pred2['prediction_label'])
# Out:
# 0.9875

# %%
# 評估調整後的模型
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(stacker_model, plot='auc' )
plot_model(rf, plot='auc' )

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# 假設模型對測試集的預測結果存儲在y_score中，真實標籤存儲在y_true中
fpr, tpr, thresholds = roc_curve(pred['GDM'], pred['prediction_score'])
roc_auc = auc(fpr, tpr)

# 繪製ROC曲線
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Step 6: 模型集成
# 使用Bagging集成多個最優分類器
#ensemble_model = ensemble_model(model, method='Bagging')

# %%
# Step 7: 模型評估
from sklearn.metrics import classification_report, confusion_matrix

# 預測測試集數據
predictions = predict_model(model, data=test_data)

# 計算混淆矩陣和分類報告
cm = confusion_matrix(predictions['GDM'], predictions['prediction_label'])
report = classification_report(predictions['GDM'], predictions['prediction_label'])

# 輸出混淆矩陣和分類報告
print("Confusion matrix:")
print(cm)
print("Classification report:")
print(report)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa558">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa558_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fa558_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fa558_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fa558_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fa558_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fa558_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fa558_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fa558_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa558_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa558_row0_col0" class="data row0 col0" >Stacking Classifier</td>
# ...

# %%
# Step 8: 模型解釋性分析
# 解釋模型中各個特徵的重要性
interpret_model(model)
#interpret_model(lr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23284\4077815747.py in <cell line: 3>()
#       1 # Step 8: 模型解釋性分析
#       2 # 解釋模型中各個特徵的重要性
# ----> 3 interpret_model(model)
#       4 #interpret_model(lr)
#
# D:\anaconda3\lib\site-packages\pycaret\utils\generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# D:\anaconda3\lib\site-packages\pycaret\classification\functional.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1935     """
#    1936
# -> 1937     return _CURRENT_EXPERIMENT.interpret_model(
#    1938         estimator=estimator,
#    1939         plot=plot,
#
# ...

# %%
# Step 9: 研究結果分析
# 繪製特徵重要性圖表
plot_model(model, plot='feature')


# 繪製錯誤分析圖表
plot_model(model, plot='error')

# 繪製分類器學習曲線和驗證曲線
plot_model(model, plot='learning')
plot_model

# %%
# 繪製ROC曲線和KS曲線
plot_model(model, plot='auc')
plot_model(model, plot='ks')
